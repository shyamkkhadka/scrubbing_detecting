# %%
# Python code that takes input as date(yyyy/mm/dd/) and ASN from a user
# Fetch ROA records from https://ftp.ripe.net/rpki/ripencc.tal/yyyy/mm/dd/roas.csv.xz. 
# It has fields: fields: URI, ASN, IP Prefix, Max Length, Not Before, Not After
# Show prefixes with that ASN
import lzma
import csv
import requests
from io import BytesIO
from datetime import datetime

def fetch_roas(date_str: str, asn_input: str):
    try:
        # Validate and parse date
        date_obj = datetime.strptime(date_str, '%Y/%m/%d')
        url_date = date_obj.strftime('%Y/%m/%d')
        url = f'https://ftp.ripe.net/rpki/ripencc.tal/{url_date}/roas.csv.xz'
        
        print(f"Fetching ROA data from: {url}")
        response = requests.get(url)
        response.raise_for_status()

        # Decompress .xz content
        with lzma.open(BytesIO(response.content)) as f:
            csv_reader = csv.DictReader(f.read().decode().splitlines())
            
            print(f"ROA Records for ASN {asn_input} on {date_str}:\n")
            found = False
            for row in csv_reader:
                if row['ASN'].strip().upper() == asn_input.upper():
                    print(f"{row['IP Prefix']} (Max Length: {row['Max Length']})")
                    found = True

            if not found:
                print("No records found for that ASN.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage
if __name__ == "__main__":
    date_input = input("Enter date (yyyy/mm/dd): ").strip()
    asn_input = input("Enter ASN (e.g., AS12345): ").strip()
    fetch_roas(date_input, asn_input)

# %%
# Python code that takes input as date(yyyy/mm/dd/), prefix and ASN from a user
# Fetch ROA records from all TALs:
# https://ftp.ripe.net/rpki/ripencc.tal/yyyy/mm/dd/roas.csv.xz. 
# It has fields: fields: URI, ASN, IP Prefix, Max Length, Not Before, Not After
# Show prefixes with that ASN
import lzma
import csv
import requests
from io import BytesIO
from datetime import datetime
import ipaddress

# List of RIRs
urls = ["ripencc", "apnic", "arin", "afrinic", "lacnic"]

def fetch_roas(date_str: str, prefix_input: str, asn_input: str):
    try:
        # Parse the input date
        date_obj = datetime.strptime(date_str, '%Y/%m/%d')
        url_date = date_obj.strftime('%Y/%m/%d')

        # Normalize prefix input
        target_prefix = ipaddress.ip_network(prefix_input, strict=False)
        found = False

        print(f"Looking for ROA of prefix {prefix_input} for ASN {asn_input} on {date_str}:\n")

        for rir in urls:
            try:
                url = f'https://ftp.ripe.net/rpki/{rir}.tal/{url_date}/roas.csv.xz'
                print(f"Checking {rir.upper()}...")

                response = requests.get(url, timeout=10)
                response.raise_for_status()

                # Decompress .xz content
                with lzma.open(BytesIO(response.content)) as f:
                    csv_reader = csv.DictReader(f.read().decode().splitlines())

                    for row in csv_reader:
                        roa_prefix = row['IP Prefix'].strip()
                        roa_asn = row['ASN'].strip().upper()
                        max_length = int(row['Max Length'])

                        if roa_asn != asn_input.upper():
                            continue

                        roa_net = ipaddress.ip_network(roa_prefix, strict=False)

                        # Skip mismatched versions (e.g., IPv4 vs IPv6)
                        if target_prefix.version != roa_net.version:
                            continue

                        # Check if target prefix is within the ROA prefix range
                        if target_prefix.subnet_of(roa_net) and target_prefix.prefixlen <= max_length:
                            print(f"✅ Found in {rir.upper()}: {roa_prefix} (Max Length: {max_length})")
                            found = True
                            
            except requests.exceptions.RequestException as e:
                print(f"  ⚠️ Failed to fetch from {rir.upper()}: {e}")
            except Exception as e:
                print(f"  ⚠️ Error processing {rir.upper()}: {e}")

        if not found:
            print("\n❌ No valid ROA found for that prefix and ASN on the given date.")
        else:
            print("\n Completed and ROA exists. ")
        
    except Exception as e:
        print(f"\nError: {e}")

# Example usage
if __name__ == "__main__":
#     date_input = input("Enter date (yyyy/mm/dd): ").strip()
#     asn_input = input("Enter ASN (e.g., AS12345): ").strip()
#     prefix_input = input("Enter prefix (e.g., 203.0.113.0/24): ").strip()
    date_input = "2025/05/09"
    prefix_input = "212.70.48.0/24"
    asn_input = "AS19905"
    fetch_roas(date_input, prefix_input, asn_input)

# %%
import lzma
import csv
import requests
from io import BytesIO
from datetime import datetime
from collections import defaultdict

def fetch_roas_and_save_conflicts(date_str: str, target_asn: str):
    tal = "apnic"   
    siblings_map = {
        "AS32787": ["AS35994",  "AS16625",  "AS36183",  "AS12222",  "AS31984",  "AS17204",  "AS26008",  
                    "AS18717",  "AS393234",  "AS393560",  "AS33047",  "AS23454",  "AS36029",  "AS18680",  
                    "AS17334", "AS22207",  "AS16702",  "AS23455",  "AS22452",  "AS30675",  "AS20189",  
                    "AS35993"], # Akamai
        "AS13335": ["AS209242", "AS395747", "AS14789", "AS394536"], # Cloudflare
        "AS19905": ["AS12008",  "AS19911",  "AS397224",  "AS399163",  "AS399156",  "AS397219",  "AS399169",  "AS399170",  
                "AS399164",  "AS397233",  "AS399167",  "AS397229",  "AS397239",  "AS397222",  "AS397235",  "AS397243",  
                "AS399161",  "AS399165",  "AS397232",  "AS397238",  "AS397215",  "AS397223",  "AS399168",  "AS397225",  
                "AS399155",  "AS397218",  "AS397221",  "AS399158",  "AS397237",  "AS399154",  "AS397213",  "AS399159",  
                "AS399153",  "AS397220",  "AS397226",  "AS399160",  "AS399157",  "AS397231",  "AS397227",  "AS397241",  
                "AS397234",  "AS399173",  "AS397240",  "AS397228",  "AS397214",  "AS399177",  "AS397230",  "AS22701", 
                "AS399171",  "AS397216",  "AS397242",  "AS399180",  "AS399162",  "AS399179",  "AS397236",  "AS399176",  
                "AS399172",  "AS399175",  "AS399151",  "AS399166",  "AS397217",  "AS399178",  "AS399152",  "AS399174"
                   ], # Vercara   

        "AS19551": [], # Imperva
        "AS198949": ["AS48851", "AS213232"] # Radware
        "AS35280": ["AS43767"], # F5
        "AS20052": [] # Arbour Network (Netscout) # No prefixes registered in RPKI TALs
        "AS10690" : []
    }
    
    siblings = siblings_map.get(target_asn, [])

    try:
        # Parse date and prepare URL
        date_obj = datetime.strptime(date_str, '%Y/%m/%d')
        url_date = date_obj.strftime('%Y/%m/%d')
        url = f'https://ftp.ripe.net/rpki/{tal}.tal/{url_date}/roas.csv.xz'
        
        print(f"Fetching ROA data from: {url}")
        response = requests.get(url)
        response.raise_for_status()

        # Decompress and read CSV
        with lzma.open(BytesIO(response.content)) as f:
            lines = f.read().decode().splitlines()
            csv_reader = csv.DictReader(lines)
            
            prefix_to_asns = defaultdict(set)

            for row in csv_reader:
                asn = row['ASN'].strip().upper()
                prefix = row['IP Prefix'].strip()
                if asn not in siblings:
                    prefix_to_asns[prefix].add(asn)

        # Filter prefixes for the target ASN
        
        target_prefixes = set()
        for prefix, asns in prefix_to_asns.items():
            if target_asn.upper() in asns:
                target_prefixes.add(prefix)

        
        # Now find how many of those prefixes also have other ASNs
        conflict_prefixes = {prefix: asns for prefix, asns in prefix_to_asns.items() 
                             if prefix in target_prefixes and len(asns) > 1}

        # Save to CSV
        output_file = 'conflicting_roas_'+tal+'_'+target_asn+'.csv'
        with open(output_file, 'w', newline='') as csvfile:
            fieldnames = ['IP Prefix', 'ASNs']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

            for prefix, asns in conflict_prefixes.items():
                
                writer.writerow({
                    'IP Prefix': prefix,
                    'ASNs': ', '.join(sorted(asns))
                })

        print(f"\nTotal prefixes registered to {target_asn}: {len(target_prefixes)}")
        print(f"Prefixes also registered to other ASNs: {len(conflict_prefixes)}")
        print(f"Saved conflicting entries to {output_file}")
    except Exception as e:
        print(f"Error: {e}")

# Example usage
if __name__ == "__main__":
#     date_input = input("Enter date (yyyy/mm/dd): ").strip()
    date_input = "2025/06/11"
#     asn_input = input("Enter ASN (e.g., AS12345): ").strip()
    asn_input = "AS13335"
    fetch_roas_and_save_conflicts(date_input, asn_input)

# %%
# Call RIPE stat API to get the first time seen and the last time seen
import requests
from datetime import datetime

# Parameters
prefix = "212.70.48.0/24"
asn_to_match = 19905
start_time = "2025-05-09T13:39:00"
end_time = "2025-05-10T14:00:00"

# Construct API URL
url = (
    "https://stat.ripe.net/data/bgp-updates/data.json"
    f"?resource={prefix}&starttime={start_time}&endtime={end_time}"
)

# Fetch data
response = requests.get(url)
data = response.json()

# Extract relevant BGP update entries
timestamps = []

for record in data.get("data", {}).get("updates", []):
    rec_type = record["type"]
    if rec_type == "A":
        path = record["attrs"]["path"]
        if path[-1] == asn_to_match:
            timestamps.append(record["timestamp"])
            
# Report results
if timestamps:
    # Convert strings to datetime objects
    dt_objects = [datetime.fromisoformat(ts) for ts in timestamps]

    # Find min and max
    first_seen = min(dt_objects)
    last_seen = max(dt_objects)
    
    print(f"ASN {asn_to_match} seen from {first_seen} to {last_seen} UTC")
else:
    print(f"ASN {asn_to_match} was not seen at the end of any path.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 34
#      28         if path[-1] == asn_to_match:
#      29             timestamps.append(record["timestamp"])
# ---> 34 print("Earliest timestamp:", min_time)
#      35 print("Latest timestamp:", max_time)
#      38 # Report results
#
# NameError: name 'min_time' is not defined

# %%
timestamps
# Out:
# ['2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:02',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:03',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:04',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:05',
#  '2025-05-09T13:39:06',
#  '2025-05-09T13:39:06',
#  '2025-05-09T13:39:06',
#  '2025-05-09T13:39:06',
#  '2025-05-09T13:39:06',
#  '2025-05-09T13:39:06',
#  '2025-05-09T13:39:07',
#  '2025-05-09T13:39:07',
#  '2025-05-09T13:39:07',
#  '2025-05-09T13:39:07',
#  '2025-05-09T13:39:07',
#  '2025-05-09T13:39:08',
#  '2025-05-09T13:39:08',
#  '2025-05-09T13:39:08',
#  '2025-05-09T13:39:08',
#  '2025-05-09T13:39:08',
#  '2025-05-09T13:39:08',
#  '2025-05-09T13:39:09',
#  '2025-05-09T13:39:09',
#  '2025-05-09T13:39:09',
#  '2025-05-09T13:39:09',
#  '2025-05-09T13:39:10',
#  '2025-05-09T13:39:10',
#  '2025-05-09T13:39:11',
#  '2025-05-09T13:39:11',
#  '2025-05-09T13:39:11',
#  '2025-05-09T13:39:12',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:13',
#  '2025-05-09T13:39:14',
#  '2025-05-09T13:39:15',
#  '2025-05-09T13:39:15',
#  '2025-05-09T13:39:15',
#  '2025-05-09T13:39:15',
#  '2025-05-09T13:39:15',
#  '2025-05-09T13:39:15',
#  '2025-05-09T13:39:16',
#  '2025-05-09T13:39:16',
#  '2025-05-09T13:39:16',
#  '2025-05-09T13:39:17',
#  '2025-05-09T13:39:17',
#  '2025-05-09T13:39:18',
#  '2025-05-09T13:39:18',
#  '2025-05-09T13:39:18',
#  '2025-05-09T13:39:18',
#  '2025-05-09T13:39:19',
#  '2025-05-09T13:39:19',
#  '2025-05-09T13:39:20',
#  '2025-05-09T13:39:20',
#  '2025-05-09T13:39:20',
#  '2025-05-09T13:39:20',
#  '2025-05-09T13:39:21',
#  '2025-05-09T13:39:21',
#  '2025-05-09T13:39:21',
#  '2025-05-09T13:39:21',
#  '2025-05-09T13:39:21',
#  '2025-05-09T13:39:22',
#  '2025-05-09T13:39:23',
#  '2025-05-09T13:39:23',
#  '2025-05-09T13:39:24',
#  '2025-05-09T13:39:24',
#  '2025-05-09T13:39:25',
#  '2025-05-09T13:39:25',
#  '2025-05-09T13:39:25',
#  '2025-05-09T13:39:25',
#  '2025-05-09T13:39:25',
#  '2025-05-09T13:39:25',
#  '2025-05-09T13:39:26',
#  '2025-05-09T13:39:26',
#  '2025-05-09T13:39:27',
#  '2025-05-09T13:39:27',
#  '2025-05-09T13:39:27',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:28',
#  '2025-05-09T13:39:29',
#  '2025-05-09T13:39:29',
#  '2025-05-09T13:39:29',
#  '2025-05-09T13:39:29',
#  '2025-05-09T13:39:30',
#  '2025-05-09T13:39:30',
#  '2025-05-09T13:39:30',
#  '2025-05-09T13:39:30',
#  '2025-05-09T13:39:30',
#  '2025-05-09T13:39:31',
#  '2025-05-09T13:39:31',
#  '2025-05-09T13:39:31',
#  '2025-05-09T13:39:31',
#  '2025-05-09T13:39:31',
#  '2025-05-09T13:39:32',
#  '2025-05-09T13:39:32',
#  '2025-05-09T13:39:32',
#  '2025-05-09T13:39:32',
#  '2025-05-09T13:39:33',
#  '2025-05-09T13:39:33',
#  '2025-05-09T13:39:34',
#  '2025-05-09T13:39:36',
#  '2025-05-09T13:39:36',
#  '2025-05-09T13:39:36',
#  '2025-05-09T13:39:36',
#  '2025-05-09T13:39:37',
#  '2025-05-09T13:39:37',
#  '2025-05-09T13:39:38',
#  '2025-05-09T13:39:39',
#  '2025-05-09T13:39:40',
#  '2025-05-09T13:39:42',
#  '2025-05-09T13:39:43',
#  '2025-05-09T13:39:45',
#  '2025-05-09T13:39:47',
#  '2025-05-09T13:39:50',
#  '2025-05-09T13:39:51',
#  '2025-05-09T13:39:54',
#  '2025-05-09T13:39:54',
#  '2025-05-09T13:39:57',
#  '2025-05-09T13:40:00',
#  '2025-05-09T13:40:01',
#  '2025-05-09T13:40:04',
#  '2025-05-09T13:40:29',
#  '2025-05-09T13:40:30',
#  '2025-05-09T13:40:49',
#  '2025-05-09T13:42:01',
#  '2025-05-09T13:43:42',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:03',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:04',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:05',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:06',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:07',
#  '2025-05-09T13:51:08',
#  '2025-05-09T13:51:08',
#  '2025-05-09T13:51:08',
#  '2025-05-09T13:51:08',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:09',
#  '2025-05-09T13:51:10',
#  '2025-05-09T13:51:10',
#  '2025-05-09T13:51:11',
#  '2025-05-09T13:51:11',
#  '2025-05-09T13:51:12',
#  '2025-05-09T13:51:12',
#  '2025-05-09T13:51:12',
#  '2025-05-09T13:51:13',
#  '2025-05-09T13:51:13',
#  '2025-05-09T13:51:14',
#  '2025-05-09T13:51:14',
#  '2025-05-09T13:51:14',
#  '2025-05-09T13:51:14',
#  '2025-05-09T13:51:14',
#  '2025-05-09T13:51:15',
#  '2025-05-09T13:51:15',
#  '2025-05-09T13:51:15',
#  '2025-05-09T13:51:15',
#  '2025-05-09T13:51:16',
#  '2025-05-09T13:51:16',
#  '2025-05-09T13:51:16',
#  '2025-05-09T13:51:16',
#  '2025-05-09T13:51:17',
#  '2025-05-09T13:51:17',
#  '2025-05-09T13:51:17',
#  '2025-05-09T13:51:17',
#  '2025-05-09T13:51:17',
#  '2025-05-09T13:51:17',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:18',
#  '2025-05-09T13:51:19',
#  '2025-05-09T13:51:19',
#  '2025-05-09T13:51:19',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:20',
#  '2025-05-09T13:51:21',
#  '2025-05-09T13:51:22',
#  '2025-05-09T13:51:23',
#  '2025-05-09T13:51:23',
#  '2025-05-09T13:51:23',
#  '2025-05-09T13:51:23',
#  '2025-05-09T13:51:24',
#  '2025-05-09T13:51:24',
#  '2025-05-09T13:51:25',
#  '2025-05-09T13:51:26',
#  '2025-05-09T13:51:26',
#  '2025-05-09T13:51:26',
#  '2025-05-09T13:51:26',
#  '2025-05-09T13:51:27',
#  '2025-05-09T13:51:27',
#  '2025-05-09T13:51:27',
#  '2025-05-09T13:51:28',
#  '2025-05-09T13:51:28',
#  '2025-05-09T13:51:28',
#  '2025-05-09T13:51:28',
#  '2025-05-09T13:51:28',
#  '2025-05-09T13:51:28',
#  '2025-05-09T13:51:29',
#  '2025-05-09T13:51:29',
#  '2025-05-09T13:51:29',
#  '2025-05-09T13:51:29',
#  '2025-05-09T13:51:29',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:30',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:31',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:32',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:33',
#  '2025-05-09T13:51:34',
#  '2025-05-09T13:51:34',
#  '2025-05-09T13:51:34',
#  '2025-05-09T13:51:34',
#  '2025-05-09T13:51:34',
#  '2025-05-09T13:51:35',
#  '2025-05-09T13:51:35',
#  '2025-05-09T13:51:36',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:37',
#  '2025-05-09T13:51:38',
#  '2025-05-09T13:51:38',
#  '2025-05-09T13:51:38',
#  '2025-05-09T13:51:38',
#  '2025-05-09T13:51:39',
#  '2025-05-09T13:51:39',
#  '2025-05-09T13:51:39',
#  '2025-05-09T13:51:39',
#  '2025-05-09T13:51:41',
#  '2025-05-09T13:51:42',
#  '2025-05-09T13:51:44',
#  '2025-05-09T13:51:44',
#  '2025-05-09T13:51:45',
#  '2025-05-09T13:51:45',
#  '2025-05-09T13:51:45',
#  '2025-05-09T13:51:45',
#  '2025-05-09T13:51:45',
#  '2025-05-09T13:51:46',
#  '2025-05-09T13:51:46',
#  '2025-05-09T13:51:46',
#  '2025-05-09T13:51:46',
#  '2025-05-09T13:51:47',
#  '2025-05-09T13:51:47',
#  '2025-05-09T13:51:48',
#  '2025-05-09T13:51:48',
#  '2025-05-09T13:51:48',
#  '2025-05-09T13:51:48',
#  '2025-05-09T13:51:49',
#  '2025-05-09T13:51:49',
#  '2025-05-09T13:51:50',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:52',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:53',
#  '2025-05-09T13:51:54',
#  '2025-05-09T13:51:57',
#  '2025-05-09T13:51:57',
#  '2025-05-09T13:51:57',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:58',
#  '2025-05-09T13:51:59',
#  '2025-05-09T13:51:59',
#  '2025-05-09T13:51:59',
#  '2025-05-09T13:51:59',
#  '2025-05-09T13:51:59',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:01',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:02',
#  '2025-05-09T13:52:03',
#  '2025-05-09T13:52:03',
#  '2025-05-09T13:52:03',
#  '2025-05-09T13:52:03',
#  '2025-05-09T13:52:03',
#  '2025-05-09T13:52:03',
#  '2025-05-09T13:52:04',
#  '2025-05-09T13:52:05',
#  '2025-05-09T13:52:05',
#  '2025-05-09T13:52:05',
#  '2025-05-09T13:52:05',
#  '2025-05-09T13:52:06',
#  '2025-05-09T13:52:06',
#  '2025-05-09T13:52:07',
#  '2025-05-09T13:52:07',
#  '2025-05-09T13:52:07',
#  '2025-05-09T13:52:07',
#  '2025-05-09T13:52:09',
#  '2025-05-09T13:52:11',
#  '2025-05-09T13:52:20',
#  '2025-05-09T13:52:20',
#  '2025-05-09T13:52:25',
#  '2025-05-09T13:52:26',
#  '2025-05-09T13:52:27',
#  '2025-05-09T13:52:29',
#  '2025-05-09T13:52:29',
#  '2025-05-09T13:52:31',
#  '2025-05-09T13:52:32',
#  '2025-05-09T13:52:34',
#  '2025-05-09T13:52:34',
#  '2025-05-09T13:52:34',
#  '2025-05-09T13:52:34',
#  '2025-05-09T13:52:34',
#  '2025-05-09T13:52:54',
#  '2025-05-09T13:52:54',
#  '2025-05-09T13:52:55',
#  '2025-05-09T13:53:41',
#  '2025-05-09T13:55:05',
#  '2025-05-09T13:55:11',
#  '2025-05-09T13:56:29',
#  '2025-05-09T13:56:30',
#  '2025-05-09T13:56:30']

# %%
data.get("data", {}).get("updates", [])
# Out:
# [{'seq': 669947114815494,
#   'timestamp': '2025-05-09T00:04:55',
#   'type': 'A',
#   'attrs': {'source_id': '00-185.193.84.191',
#    'target_prefix': '212.70.48.0/24',
#    'path': [29504, 15935, 174, 48237, 35819, 29690],
#    'community': ['174:21101', '174:22012', '15935:200', '15935:202']}},
#  {'seq': 651782324420618,
#   'timestamp': '2025-05-09T00:17:43',
#   'type': 'A',
#   'attrs': {'source_id': '00-5.178.95.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [59919, 41327, 3257, 48237, 35819, 29690],
#    'community': ['3257:4000',
#     '3257:8804',
#     '3257:50001',
#     '3257:50110',
#     '3257:53300',
#     '3257:53302',
#     '17152:0',
#     '41327:4400',
#     '41327:10001',
#     '41327:11000',
#     '41327:11002']}},
#  {'seq': 90769510891521,
#   'timestamp': '2025-05-09T01:03:43',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.190',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37239, 5713, 174, 48237, 35819, 29690],
#    'community': ['5713:424']}},
#  {'seq': 90777806635009,
#   'timestamp': '2025-05-09T01:04:54',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.190',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37239, 37468, 12956, 2914, 48237, 35819, 29690],
#    'community': ['37468:332']}},
#  {'seq': 651794464702466,
#   'timestamp': '2025-05-09T01:04:58',
#   'type': 'A',
#   'attrs': {'source_id': '00-5.178.95.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [59919, 9002, 48237, 35819, 29690],
#    'community': ['9002:9002', '9002:64657']}},
#  {'seq': 586568029634852,
#   'timestamp': '2025-05-09T01:12:37',
#   'type': 'W',
#   'attrs': {'source_id': '15-187.16.216.131',
#    'target_prefix': '212.70.48.0/24'}},
#  {'seq': 586572499910657,
#   'timestamp': '2025-05-09T01:21:19',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.216.131',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28634, 262493, 3356, 48237, 35819, 29690],
#    'community': ['1000:10000',
#     '1000:10003',
#     '3356:2',
#     '3356:22',
#     '3356:84',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090']}},
#  {'seq': 564489117368326,
#   'timestamp': '2025-05-09T04:06:21',
#   'type': 'A',
#   'attrs': {'source_id': '24-200.40.162.202',
#    'target_prefix': '212.70.48.0/24',
#    'path': [6057, 2914, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 852462026817549,
#   'timestamp': '2025-05-09T04:23:05',
#   'type': 'A',
#   'attrs': {'source_id': '00-154.11.12.212',
#    'target_prefix': '212.70.48.0/24',
#    'path': [852, 3257, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 651837056090124,
#   'timestamp': '2025-05-09T04:23:26',
#   'type': 'A',
#   'attrs': {'source_id': '00-208.80.153.193',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 3356, 48237, 35819, 29690],
#    'community': ['3356:2',
#     '3356:22',
#     '3356:100',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090',
#     '14907:4']}},
#  {'seq': 852472199053325,
#   'timestamp': '2025-05-09T04:31:45',
#   'type': 'A',
#   'attrs': {'source_id': '00-154.11.12.212',
#    'target_prefix': '212.70.48.0/24',
#    'path': [852, 3257, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 651857804394508,
#   'timestamp': '2025-05-09T04:32:43',
#   'type': 'A',
#   'attrs': {'source_id': '00-208.80.153.193',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 3356, 48237, 35819, 29690],
#    'community': ['3356:2',
#     '3356:22',
#     '3356:100',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090',
#     '14907:4']}},
#  {'seq': 852487683506189,
#   'timestamp': '2025-05-09T04:51:52',
#   'type': 'A',
#   'attrs': {'source_id': '00-154.11.12.212',
#    'target_prefix': '212.70.48.0/24',
#    'path': [852, 3257, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 651878915637260,
#   'timestamp': '2025-05-09T04:53:10',
#   'type': 'A',
#   'attrs': {'source_id': '00-208.80.153.193',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 3356, 48237, 35819, 29690],
#    'community': ['3356:2',
#     '3356:22',
#     '3356:100',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090',
#     '14907:4']}},
#  {'seq': 176495067791363,
#   'timestamp': '2025-05-09T05:34:25',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.9.165',
#    'target_prefix': '212.70.48.0/24',
#    'path': [917, 60068, 48237, 35819, 29690],
#    'community': ['917:59001',
#     '57695:13000',
#     '60068:203',
#     '60068:300',
#     '60068:777',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 372539493842955,
#   'timestamp': '2025-05-09T05:34:25',
#   'type': 'A',
#   'attrs': {'source_id': '01-5.57.81.231',
#    'target_prefix': '212.70.48.0/24',
#    'path': [917, 60068, 48237, 35819, 29690],
#    'community': ['917:56020',
#     '57695:13000',
#     '60068:203',
#     '60068:777',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 378753213005831,
#   'timestamp': '2025-05-09T05:34:25',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.220.159',
#    'target_prefix': '212.70.48.0/24',
#    'path': [917, 60068, 48237, 35819, 29690],
#    'community': ['917:55551',
#     '57695:13000',
#     '60068:203',
#     '60068:300',
#     '60068:777',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 776276415348739,
#   'timestamp': '2025-05-09T05:34:25',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.192.231',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57695, 60068, 48237, 35819, 29690],
#    'community': ['917:56041',
#     '57695:13000',
#     '60068:203',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 776276419805192,
#   'timestamp': '2025-05-09T05:34:25',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.192.231',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57695, 60068, 48237, 35819, 29690],
#    'community': ['917:56041',
#     '57695:13000',
#     '60068:203',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 85605814501387,
#   'timestamp': '2025-05-09T05:34:29',
#   'type': 'A',
#   'attrs': {'source_id': '05-193.203.0.245',
#    'target_prefix': '212.70.48.0/24',
#    'path': [59890, 60068, 48237, 35819, 29690],
#    'community': ['59890:308',
#     '60068:203',
#     '60068:777',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 539433776185347,
#   'timestamp': '2025-05-09T05:34:34',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.38',
#    'target_prefix': '212.70.48.0/24',
#    'path': [59890, 60068, 48237, 35819, 29690],
#    'community': ['59890:308',
#     '60068:203',
#     '60068:777',
#     '60068:3000',
#     '60068:3585',
#     '60068:7140']}},
#  {'seq': 69208623808522,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '05-193.203.0.182',
#    'target_prefix': '212.70.48.0/24',
#    'path': [48362, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 176495270363147,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.9.84',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37697, 37497, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '37497:4201',
#     '37697:2000']}},
#  {'seq': 281125415944202,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '07-194.68.123.226',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 305009862311948,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.66.158',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 307428901126156,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.228',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 349292336906243,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.233',
#    'target_prefix': '212.70.48.0/24',
#    'path': [207841, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012']}},
#  {'seq': 372539721187331,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.231.56',
#    'target_prefix': '212.70.48.0/24',
#    'path': [271253, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 372539722366987,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.160',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3214, 48237, 35819, 29690],
#    'community': ['3214:100', '3214:4401']}},
#  {'seq': 376674760327180,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '25-193.107.13.3',
#    'target_prefix': '212.70.48.0/24',
#    'path': [47787, 6424, 48237, 35819, 29690],
#    'community': ['47787:1010', '47787:3120', '47787:20000', '47787:21130']}},
#  {'seq': 376674761572363,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '25-185.255.53.202',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3214, 48237, 35819, 29690],
#    'community': ['3214:100', '3214:4401']}},
#  {'seq': 378837598666755,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '13-195.208.209.66',
#    'target_prefix': '212.70.48.0/24',
#    'path': [35598, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '35598:300',
#     '35598:307']}},
#  {'seq': 381340936765446,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.40',
#    'target_prefix': '212.70.48.0/24',
#    'path': [48362, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 396632655331331,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.225.212',
#    'target_prefix': '212.70.48.0/24',
#    'path': [6424, 48237, 35819, 29690],
#    'community': ['47787:1010', '47787:3120', '47787:20000', '47787:21130']}},
#  {'seq': 396632656248835,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.193',
#    'target_prefix': '212.70.48.0/24',
#    'path': [6233, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012']}},
#  {'seq': 403772239511555,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.195',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3170, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '60945:0',
#     '60945:8714']}},
#  {'seq': 405156626759683,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.226.97',
#    'target_prefix': '212.70.48.0/24',
#    'path': [39122, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012']}},
#  {'seq': 405156629577731,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.224.81',
#    'target_prefix': '212.70.48.0/24',
#    'path': [1828, 48237, 35819, 29690],
#    'community': ['1828:20', '1828:23301']}},
#  {'seq': 421245735403532,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.226.113',
#    'target_prefix': '212.70.48.0/24',
#    'path': [42473, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '47147:1500',
#     '47147:2000',
#     '47147:2112',
#     '47147:2301',
#     '47147:2305',
#     '47147:2416',
#     '47147:2712']}},
#  {'seq': 423316365246466,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '11-198.32.160.242',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 425908422180865,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.226.18',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37721, 48237, 35819, 29690],
#    'community': ['37721:3000', '37721:3200', '37721:3210', '37721:3211']}},
#  {'seq': 427747755753481,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.5',
#    'target_prefix': '212.70.48.0/24',
#    'path': [5405, 48237, 35819, 29690],
#    'community': ['5405:3',
#     '5405:15',
#     '5405:221',
#     '5405:3012',
#     '5405:4024',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012']}},
#  {'seq': 445765367955457,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.180',
#    'target_prefix': '212.70.48.0/24',
#    'path': [62167, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 487808905510920,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.210.153',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 511912621113356,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.127',
#    'target_prefix': '212.70.48.0/24',
#    'path': [20612, 9044, 48237, 35819, 29690],
#    'community': ['20612:9044']}},
#  {'seq': 526959623602184,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.225.48',
#    'target_prefix': '212.70.48.0/24',
#    'path': [62167, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 526959629041667,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.105',
#    'target_prefix': '212.70.48.0/24',
#    'path': [34927, 48237, 35819, 29690],
#    'community': ['34927:530']}},
#  {'seq': 529614065631244,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.205',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 542113386856451,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.226.38',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 567753090727939,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.210.207',
#    'target_prefix': '212.70.48.0/24',
#    'path': [35598, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '35598:300',
#     '35598:307']}},
#  {'seq': 603754619863050,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.193.139',
#    'target_prefix': '212.70.48.0/24',
#    'path': [48362, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 608152542248963,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.196.156',
#    'target_prefix': '212.70.48.0/24',
#    'path': [34927, 48237, 35819, 29690],
#    'community': ['34927:530', '34927:9652']}},
#  {'seq': 705468335718412,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.126',
#    'target_prefix': '212.70.48.0/24',
#    'path': [20612, 9044, 48237, 35819, 29690],
#    'community': ['20612:9044']}},
#  {'seq': 743802392936451,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '03-193.239.118.220',
#    'target_prefix': '212.70.48.0/24',
#    'path': [209650, 34927, 48237, 35819, 29690],
#    'community': ['34927:530', '34927:9652']}},
#  {'seq': 776276690599942,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.194.119',
#    'target_prefix': '212.70.48.0/24',
#    'path': [34288, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '65500:50000',
#     '65500:59000',
#     '65500:59120',
#     '65500:59121']}},
#  {'seq': 859752796061706,
#   'timestamp': '2025-05-09T05:35:30',
#   'type': 'A',
#   'attrs': {'source_id': '00-185.210.224.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [49432, 48362, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 79194539163651,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '26-185.1.8.50',
#    'target_prefix': '212.70.48.0/24',
#    'path': [200612, 51375, 39386, 48237, 35819, 29690],
#    'community': ['20061:41426']}},
#  {'seq': 81488816373766,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.221',
#    'target_prefix': '212.70.48.0/24',
#    'path': [327804, 5713, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 145164674138121,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.139',
#    'target_prefix': '212.70.48.0/24',
#    'path': [32653, 3741, 48237, 35819, 29690],
#    'community': ['3741:1000',
#     '3741:1010',
#     '3741:1011',
#     '3741:1118',
#     '3741:4200',
#     '3741:44191',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '32653:200',
#     '32653:21110']}},
#  {'seq': 182353265295371,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '16-198.32.242.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [52320, 48237, 35819, 29690],
#    'community': ['52320:21311']}},
#  {'seq': 211908966940677,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '05-193.203.0.91',
#    'target_prefix': '212.70.48.0/24',
#    'path': [13237, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 257041635147788,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '13-195.208.210.52',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41722, 20764, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '20764:3000',
#     '20764:3020',
#     '20764:3035',
#     '20764:3101',
#     '41722:50']}},
#  {'seq': 329969303093253,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '24-186.211.184.34',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14840, 48237, 35819, 29690],
#    'community': ['14840:20', '14840:40', '14840:4005', '14840:7001']}},
#  {'seq': 329969303552004,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '24-186.211.136.32',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14840, 48237, 35819, 29690],
#    'community': ['14840:20', '14840:40', '14840:4005', '14840:7001']}},
#  {'seq': 358750260887558,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.208.144',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 370368411074563,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '25-178.248.51.149',
#    'target_prefix': '212.70.48.0/24',
#    'path': [51185, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 370368413171724,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '25-85.132.60.12',
#    'target_prefix': '212.70.48.0/24',
#    'path': [29049, 20764, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '20764:3000',
#     '20764:3020',
#     '20764:3035',
#     '20764:3101']}},
#  {'seq': 378837602074632,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '13-195.208.208.223',
#    'target_prefix': '212.70.48.0/24',
#    'path': [20764, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '20764:3000',
#     '20764:3020',
#     '20764:3035',
#     '20764:3101']}},
#  {'seq': 378837610397702,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '13-195.208.209.109',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 396632664965123,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.90',
#    'target_prefix': '212.70.48.0/24',
#    'path': [51185, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 701589057110019,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '03-193.239.116.134',
#    'target_prefix': '212.70.48.0/24',
#    'path': [212483, 48237, 35819, 29690],
#    'community': ['64700:8714']}},
#  {'seq': 701589057175555,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '03-2001:7f8:13::a521:2483:1',
#    'target_prefix': '212.70.48.0/24',
#    'path': [212483, 48237, 35819, 29690],
#    'community': ['64700:8714']}},
#  {'seq': 701589060648963,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '03-193.239.116.134',
#    'target_prefix': '212.70.48.0/24',
#    'path': [212483, 48237, 35819, 29690],
#    'community': ['64700:8714']}},
#  {'seq': 701589060714499,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '03-2001:7f8:13::a521:2483:1',
#    'target_prefix': '212.70.48.0/24',
#    'path': [212483, 48237, 35819, 29690],
#    'community': ['64700:8714']}},
#  {'seq': 743802400735236,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.209.255',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3214, 48237, 35819, 29690],
#    'community': ['3214:100', '3214:4401']}},
#  {'seq': 776276701085702,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.193.18',
#    'target_prefix': '212.70.48.0/24',
#    'path': [24482, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '24482:2',
#     '24482:200',
#     '24482:12000',
#     '24482:12010',
#     '24482:12011',
#     '24482:65201']}},
#  {'seq': 932343308025859,
#   'timestamp': '2025-05-09T05:35:31',
#   'type': 'A',
#   'attrs': {'source_id': '00-202.69.160.152',
#    'target_prefix': '212.70.48.0/24',
#    'path': [17639, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 90794726916103,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.190',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37239, 37468, 48237, 35819, 29690],
#    'community': ['37468:332']}},
#  {'seq': 153721102598147,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.237.83',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25091, 48237, 35819, 29690],
#    'community': ['25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 329969315872775,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '24-177.221.140.2',
#    'target_prefix': '212.70.48.0/24',
#    'path': [270014, 263237, 6939, 48237, 35819, 29690],
#    'community': ['65237:6939']}},
#  {'seq': 344840427733005,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '25-45.67.83.250',
#    'target_prefix': '212.70.48.0/24',
#    'path': [207910, 34019, 25091, 48237, 35819, 29690],
#    'community': ['34019:25091', '34019:65535', '65512:20001']}},
#  {'seq': 358750267637763,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.222.45',
#    'target_prefix': '212.70.48.0/24',
#    'path': [263237, 6939, 48237, 35819, 29690],
#    'community': ['65237:6939']}},
#  {'seq': 372539741372427,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.226.13',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8896, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 403772254781443,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.225.216',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25160, 48237, 35819, 29690],
#    'community': ['25160:31', '8714:33438', '8714:65010', '8714:65012']}},
#  {'seq': 427747761061890,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.141',
#    'target_prefix': '212.70.48.0/24',
#    'path': [59891, 51395, 6939, 48237, 35819, 29690],
#    'community': ['59891:1000', '59891:1002']}},
#  {'seq': 457169095426058,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '25-27.50.36.146',
#    'target_prefix': '212.70.48.0/24',
#    'path': [134823, 3491, 3257, 48237, 35819, 29690],
#    'community': ['3257:4000',
#     '3257:8804',
#     '3257:50001',
#     '3257:50110',
#     '3257:53300',
#     '3257:53302',
#     '3491:4000',
#     '3491:4015',
#     '3491:9002',
#     '38042:10016',
#     '38042:15003']}},
#  {'seq': 511912634286083,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.12',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8298, 25091, 48237, 35819, 29690],
#    'community': ['8298:2000', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 511912635006979,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.12',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8298, 25091, 48237, 35819, 29690],
#    'community': ['8298:2000', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 539433924231171,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.35',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57777, 8298, 25091, 48237, 35819, 29690],
#    'community': ['8298:2000', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 558115968188418,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '03-193.239.116.60',
#    'target_prefix': '212.70.48.0/24',
#    'path': [399580, 6939, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 558115968385027,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '03-193.239.116.60',
#    'target_prefix': '212.70.48.0/24',
#    'path': [399580, 6939, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 597554682724355,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '03-193.239.117.30',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41047, 48237, 35819, 29690],
#    'community': ['41047:2100', '64700:8714']}},
#  {'seq': 727724406407171,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '00-185.102.84.232',
#    'target_prefix': '212.70.48.0/24',
#    'path': [61218, 6939, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 859752816377858,
#   'timestamp': '2025-05-09T05:35:32',
#   'type': 'A',
#   'attrs': {'source_id': '00-165.16.221.66',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37721, 48237, 35819, 29690],
#    'community': ['37721:3000', '37721:3200', '37721:3210', '37721:3211']}},
#  {'seq': 400384779419654,
#   'timestamp': '2025-05-09T05:35:33',
#   'type': 'A',
#   'attrs': {'source_id': '25-185.115.244.25',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28824, 50304, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '28824:1400',
#     '50304:1100',
#     '50304:1144']}},
#  {'seq': 421245746741259,
#   'timestamp': '2025-05-09T05:35:33',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.226.232',
#    'target_prefix': '212.70.48.0/24',
#    'path': [12969, 48237, 35819, 29690],
#    'community': ['12969:20', '12969:22', '12969:8714', '12969:30826']}},
#  {'seq': 487808922746893,
#   'timestamp': '2025-05-09T05:35:33',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.210.134',
#    'target_prefix': '212.70.48.0/24',
#    'path': [34019, 25091, 48237, 35819, 29690],
#    'community': ['34019:25091', '34019:65535', '65512:20001']}},
#  {'seq': 558115981623299,
#   'timestamp': '2025-05-09T05:35:34',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.210.85',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25160, 48237, 35819, 29690],
#    'community': ['25160:31', '8714:33438', '8714:65010', '8714:65012']}},
#  {'seq': 153721121275915,
#   'timestamp': '2025-05-09T05:35:35',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.32',
#    'target_prefix': '212.70.48.0/24',
#    'path': [34177, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 452814008090636,
#   'timestamp': '2025-05-09T05:35:35',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.222.156',
#    'target_prefix': '212.70.48.0/24',
#    'path': [264479, 7195, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 1258202649264134,
#   'timestamp': '2025-05-09T05:35:36',
#   'type': 'A',
#   'attrs': {'source_id': '00-49.12.70.222',
#    'target_prefix': '212.70.48.0/24',
#    'path': [44393, 58057, 6939, 48237, 35819, 29690],
#    'community': ['58057:65010']}},
#  {'seq': 609715587842052,
#   'timestamp': '2025-05-09T05:35:38',
#   'type': 'A',
#   'attrs': {'source_id': '25-102.220.17.28',
#    'target_prefix': '212.70.48.0/24',
#    'path': [328840, 37282, 48237, 35819, 29690],
#    'community': ['64525:61']}},
#  {'seq': 143597057015813,
#   'timestamp': '2025-05-09T05:35:39',
#   'type': 'A',
#   'attrs': {'source_id': '05-193.203.0.63',
#    'target_prefix': '212.70.48.0/24',
#    'path': [6720, 1853, 6939, 48237, 35819, 29690],
#    'community': ['1120:1']}},
#  {'seq': 403442028183556,
#   'timestamp': '2025-05-09T05:35:39',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.172',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58308, 59689, 29075, 48237, 35819, 29690],
#    'community': ['0:0',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '29075:6700']}},
#  {'seq': 403772267823107,
#   'timestamp': '2025-05-09T05:35:40',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.227.148',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14630, 48237, 35819, 29690],
#    'community': ['8714:5001',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '14630:9']}},
#  {'seq': 500424081997827,
#   'timestamp': '2025-05-09T05:35:40',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.212.10',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50629, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '50629:200',
#     '50629:420',
#     '50629:10003',
#     '50629:10108',
#     '50629:10214']}},
#  {'seq': 568318934319107,
#   'timestamp': '2025-05-09T05:35:40',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.194.240',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50629, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '50629:200',
#     '50629:420',
#     '50629:10003',
#     '50629:10108',
#     '50629:10214']}},
#  {'seq': 145164682199049,
#   'timestamp': '2025-05-09T05:35:41',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.139',
#    'target_prefix': '212.70.48.0/24',
#    'path': [32653, 3741, 48237, 35819, 29690],
#    'community': ['3741:1000',
#     '3741:1010',
#     '3741:1011',
#     '3741:1118',
#     '3741:4200',
#     '3741:44171',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '32653:200',
#     '32653:21110']}},
#  {'seq': 445765428183053,
#   'timestamp': '2025-05-09T05:35:41',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.15',
#    'target_prefix': '212.70.48.0/24',
#    'path': [15623, 4455, 48237, 35819, 29690],
#    'community': ['15623:2000', '15623:2091']}},
#  {'seq': 511912664301571,
#   'timestamp': '2025-05-09T05:35:41',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.12',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8298, 25091, 48237, 35819, 29690],
#    'community': ['8298:2000', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 46043385626636,
#   'timestamp': '2025-05-09T05:35:42',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.51',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41327, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '17152:0',
#     '41327:4100',
#     '41327:4128',
#     '41327:10001',
#     '41327:15000',
#     '41327:15001']}},
#  {'seq': 239959185752068,
#   'timestamp': '2025-05-09T05:35:42',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.13',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57111, 41327, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '17152:0',
#     '41327:4100',
#     '41327:4128',
#     '41327:10001',
#     '41327:15000',
#     '41327:15001']}},
#  {'seq': 928870387351668,
#   'timestamp': '2025-05-09T05:35:42',
#   'type': 'W',
#   'attrs': {'source_id': '00-45.134.89.1', 'target_prefix': '212.70.48.0/24'}},
#  {'seq': 511912670855171,
#   'timestamp': '2025-05-09T05:35:44',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.12',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8298, 25091, 48237, 35819, 29690],
#    'community': ['8298:2000', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 852501680816133,
#   'timestamp': '2025-05-09T05:35:44',
#   'type': 'A',
#   'attrs': {'source_id': '00-94.247.111.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [49673, 3216, 48237, 35819, 29690],
#    'community': ['3216:3000',
#     '3216:3102',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012']}},
#  {'seq': 288230903316484,
#   'timestamp': '2025-05-09T05:35:45',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.205',
#    'target_prefix': '212.70.48.0/24',
#    'path': [29075, 48237, 35819, 29690],
#    'community': ['0:0',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '29075:6700']}},
#  {'seq': 460093610983430,
#   'timestamp': '2025-05-09T05:35:46',
#   'type': 'A',
#   'attrs': {'source_id': '25-195.69.189.4',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28910, 20764, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 859752873000965,
#   'timestamp': '2025-05-09T05:35:46',
#   'type': 'A',
#   'attrs': {'source_id': '00-202.150.221.37',
#    'target_prefix': '212.70.48.0/24',
#    'path': [38001, 9002, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 511912683962371,
#   'timestamp': '2025-05-09T05:35:47',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.53.12',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8298, 25091, 48237, 35819, 29690],
#    'community': ['8298:2000', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 539433971482627,
#   'timestamp': '2025-05-09T05:35:47',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.117',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25091, 48237, 35819, 29690],
#    'community': ['25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 403442041487364,
#   'timestamp': '2025-05-09T05:35:48',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.172',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58308, 59689, 29075, 48237, 35819, 29690],
#    'community': ['0:0',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '29075:6700']}},
#  {'seq': 609715726123012,
#   'timestamp': '2025-05-09T05:35:49',
#   'type': 'A',
#   'attrs': {'source_id': '25-102.220.16.1',
#    'target_prefix': '212.70.48.0/24',
#    'path': [328840, 60171, 48237, 35819, 29690],
#    'community': ['60171:200', '60171:220', '60171:221', '64525:51']}},
#  {'seq': 421245792747531,
#   'timestamp': '2025-05-09T05:35:50',
#   'type': 'A',
#   'attrs': {'source_id': '01-5.57.81.127',
#    'target_prefix': '212.70.48.0/24',
#    'path': [48070, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 457169177673734,
#   'timestamp': '2025-05-09T05:35:50',
#   'type': 'A',
#   'attrs': {'source_id': '25-93.190.135.253',
#    'target_prefix': '212.70.48.0/24',
#    'path': [6881, 15685, 6939, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 82791414890499,
#   'timestamp': '2025-05-09T05:35:52',
#   'type': 'A',
#   'attrs': {'source_id': '04-192.65.185.244',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25091, 48237, 35819, 29690],
#    'community': ['25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 90410201579529,
#   'timestamp': '2025-05-09T05:35:52',
#   'type': 'A',
#   'attrs': {'source_id': '04-192.65.185.3',
#    'target_prefix': '212.70.48.0/24',
#    'path': [513, 25091, 25091, 48237, 35819, 29690],
#    'community': ['513:25091', '25091:27412', '65400:8714', '65401:412']}},
#  {'seq': 377462084206599,
#   'timestamp': '2025-05-09T05:35:53',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.246',
#    'target_prefix': '212.70.48.0/24',
#    'path': [51786, 15623, 4455, 48237, 35819, 29690],
#    'community': ['15623:2000', '15623:2091']}},
#  {'seq': 305127802011656,
#   'timestamp': '2025-05-09T05:35:54',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.246',
#    'target_prefix': '212.70.48.0/24',
#    'path': [2613, 6893, 29075, 48237, 35819, 29690],
#    'community': ['2613:12345']}},
#  {'seq': 376674816491530,
#   'timestamp': '2025-05-09T05:35:54',
#   'type': 'A',
#   'attrs': {'source_id': '25-31.15.255.209',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3212, 6939, 48237, 35819, 29690],
#    'community': ['6939:500']}},
#  {'seq': 478882253045764,
#   'timestamp': '2025-05-09T05:35:57',
#   'type': 'A',
#   'attrs': {'source_id': '01-5.57.81.216',
#    'target_prefix': '212.70.48.0/24',
#    'path': [35266, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '35266:70',
#     '35266:110']}},
#  {'seq': 669973950496779,
#   'timestamp': '2025-05-09T05:35:57',
#   'type': 'A',
#   'attrs': {'source_id': '00-89.42.52.8',
#    'target_prefix': '212.70.48.0/24',
#    'path': [213241, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 400384836829190,
#   'timestamp': '2025-05-09T05:35:59',
#   'type': 'A',
#   'attrs': {'source_id': '25-185.115.244.25',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28824, 8896, 48237, 35819, 29690],
#    'community': ['8896:2150', '8896:2330', '28824:1400']}},
#  {'seq': 705540831248388,
#   'timestamp': '2025-05-09T05:35:59',
#   'type': 'A',
#   'attrs': {'source_id': '00-193.150.22.240',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57381, 50304, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '50304:1100',
#     '50304:1144']}},
#  {'seq': 932343387324420,
#   'timestamp': '2025-05-09T05:35:59',
#   'type': 'A',
#   'attrs': {'source_id': '00-31.169.49.228',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50304, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 66963276038153,
#   'timestamp': '2025-05-09T05:36:00',
#   'type': 'A',
#   'attrs': {'source_id': '24-138.122.60.1',
#    'target_prefix': '212.70.48.0/24',
#    'path': [61573, 37468, 48237, 35819, 29690],
#    'community': ['37468:2001', '37468:2102', '65000:8714']}},
#  {'seq': 372539819425799,
#   'timestamp': '2025-05-09T05:36:00',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.224.131',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28792, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 499225511526402,
#   'timestamp': '2025-05-09T05:36:02',
#   'type': 'A',
#   'attrs': {'source_id': '25-192.154.3.129',
#    'target_prefix': '212.70.48.0/24',
#    'path': [394414, 32621, 6939, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 542113490141188,
#   'timestamp': '2025-05-09T05:36:02',
#   'type': 'A',
#   'attrs': {'source_id': '01-5.57.81.210',
#    'target_prefix': '212.70.48.0/24',
#    'path': [31742, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 603754824204289,
#   'timestamp': '2025-05-09T05:36:20',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.194.100',
#    'target_prefix': '212.70.48.0/24',
#    'path': [47692, 33891, 48237, 35819, 29690],
#    'community': ['33891:2819',
#     '33891:33893',
#     '33891:33900',
#     '33891:40051',
#     '47692:30000',
#     '47692:30140']}},
#  {'seq': 572712519073805,
#   'timestamp': '2025-05-09T05:36:23',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.44',
#    'target_prefix': '212.70.48.0/24',
#    'path': [327983, 37497, 48237, 35819, 29690],
#    'community': ['37497:4201', '8714:33438', '8714:65010', '8714:65012']}},
#  {'seq': 568319056478211,
#   'timestamp': '2025-05-09T05:36:30',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.195.219',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58057, 34549, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012', '34549:14000']}},
#  {'seq': 859753060958218,
#   'timestamp': '2025-05-09T05:36:30',
#   'type': 'A',
#   'attrs': {'source_id': '00-80.77.16.114',
#    'target_prefix': '212.70.48.0/24',
#    'path': [34549, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012', '34549:14000']}},
#  {'seq': 932343454367747,
#   'timestamp': '2025-05-09T05:36:30',
#   'type': 'A',
#   'attrs': {'source_id': '00-194.50.92.251',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58057, 34549, 48237, 35819, 29690],
#    'community': ['0:34927',
#     '0:56382',
#     '0:58299',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '34549:14000']}},
#  {'seq': 932343456858122,
#   'timestamp': '2025-05-09T05:36:30',
#   'type': 'A',
#   'attrs': {'source_id': '00-194.50.92.251',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58057, 34549, 48237, 35819, 29690],
#    'community': ['0:34927',
#     '0:56382',
#     '0:58299',
#     '8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '34549:14000']}},
#  {'seq': 400384906166273,
#   'timestamp': '2025-05-09T05:36:31',
#   'type': 'A',
#   'attrs': {'source_id': '25-186.211.216.32',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14840, 48237, 35819, 29690],
#    'community': ['14840:20', '14840:40', '14840:4005', '14840:7001']}},
#  {'seq': 568319063293962,
#   'timestamp': '2025-05-09T05:36:31',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.195.219',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58057, 34549, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012', '34549:14000']}},
#  {'seq': 568319064014851,
#   'timestamp': '2025-05-09T05:36:31',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.196.225',
#    'target_prefix': '212.70.48.0/24',
#    'path': [213151, 34549, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 608152685248522,
#   'timestamp': '2025-05-09T05:36:31',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.196.197',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58299, 34549, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '34549:14000',
#     '58299:1000']}},
#  {'seq': 651894191685642,
#   'timestamp': '2025-05-09T05:36:33',
#   'type': 'A',
#   'attrs': {'source_id': '00-45.14.68.69',
#    'target_prefix': '212.70.48.0/24',
#    'path': [206499, 34549, 48237, 35819, 29690],
#    'community': ['8714:33438', '8714:65010', '8714:65012', '34549:14000']}},
#  {'seq': 932343713890308,
#   'timestamp': '2025-05-09T05:38:37',
#   'type': 'A',
#   'attrs': {'source_id': '00-176.12.110.8',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50300, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 452818584403976,
#   'timestamp': '2025-05-09T06:07:58',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.209.34',
#    'target_prefix': '212.70.48.0/24',
#    'path': [271253, 174, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 586593793146881,
#   'timestamp': '2025-05-09T06:09:22',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.216.131',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28634, 262493, 7195, 48237, 35819, 29690],
#    'community': ['0:2000',
#     '1000:10000',
#     '1000:10006',
#     '7195:44000',
#     '7195:44001',
#     '7195:44300']}},
#  {'seq': 452820941013004,
#   'timestamp': '2025-05-09T06:09:53',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.209.34',
#    'target_prefix': '212.70.48.0/24',
#    'path': [271253, 3356, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 852512384745485,
#   'timestamp': '2025-05-09T06:19:53',
#   'type': 'A',
#   'attrs': {'source_id': '00-154.11.12.212',
#    'target_prefix': '212.70.48.0/24',
#    'path': [852, 3257, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 651908056547340,
#   'timestamp': '2025-05-09T06:20:33',
#   'type': 'A',
#   'attrs': {'source_id': '00-208.80.153.193',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 3356, 48237, 35819, 29690],
#    'community': ['3356:2',
#     '3356:22',
#     '3356:100',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090',
#     '14907:4']}},
#  {'seq': 852526815838221,
#   'timestamp': '2025-05-09T06:38:44',
#   'type': 'A',
#   'attrs': {'source_id': '00-154.11.12.212',
#    'target_prefix': '212.70.48.0/24',
#    'path': [852, 3257, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 651926134784012,
#   'timestamp': '2025-05-09T06:39:16',
#   'type': 'A',
#   'attrs': {'source_id': '00-208.80.153.193',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 3356, 48237, 35819, 29690],
#    'community': ['3356:2',
#     '3356:22',
#     '3356:100',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090',
#     '14907:4']}},
#  {'seq': 239966151966724,
#   'timestamp': '2025-05-09T07:12:35',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.13',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57111, 41327, 3257, 48237, 35819, 29690],
#    'community': ['3257:4000',
#     '3257:8804',
#     '3257:50001',
#     '3257:50110',
#     '3257:53300',
#     '3257:53302',
#     '17152:0',
#     '41327:4400',
#     '41327:10001',
#     '41327:11000',
#     '41327:11003']}},
#  {'seq': 46045399810055,
#   'timestamp': '2025-05-09T07:12:36',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.51',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41327, 3257, 48237, 35819, 29690],
#    'community': ['3257:4000',
#     '3257:8804',
#     '3257:50001',
#     '3257:50110',
#     '3257:53300',
#     '3257:53302',
#     '17152:0',
#     '41327:4400',
#     '41327:10001',
#     '41327:11000',
#     '41327:11002']}},
#  {'seq': 239966622121988,
#   'timestamp': '2025-05-09T07:18:56',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.13',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57111, 41327, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '17152:0',
#     '41327:4100',
#     '41327:4128',
#     '41327:10001',
#     '41327:15000',
#     '41327:15001']}},
#  {'seq': 46045625253900,
#   'timestamp': '2025-05-09T07:19:01',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.51',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41327, 48237, 35819, 29690],
#    'community': ['8714:33438',
#     '8714:65010',
#     '8714:65012',
#     '17152:0',
#     '41327:4100',
#     '41327:4128',
#     '41327:10001',
#     '41327:15000',
#     '41327:15001']}},
#  {'seq': 336349729914886,
#   'timestamp': '2025-05-09T07:33:35',
#   'type': 'A',
#   'attrs': {'source_id': '23-27.111.228.186',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 1299, 48237, 35819, 29690],
#    'community': ['1299:30000', '14907:0', '14907:4']}},
#  {'seq': 336349739220997,
#   'timestamp': '2025-05-09T07:33:35',
#   'type': 'A',
#   'attrs': {'source_id': '23-27.111.228.186',
#    'target_prefix': '212.70.48.0/24',
#    'path': [14907, 2914, 48237, 35819, 29690],
#    'community': ['2914:410',
#     '2914:1405',
#     '2914:2406',
#     '2914:3400',
#     '14907:4']}},
#  {'seq': 104863088902154,
#   'timestamp': '2025-05-09T07:33:54',
#   'type': 'A',
#   'attrs': {'source_id': '23-27.111.228.222',
#    'target_prefix': '212.70.48.0/24',
#    'path': [199524, 1299, 48237, 35819, 29690],
#    'community': []}},
#  {'seq': 406616211324932,
#   'timestamp': '2025-05-09T07:43:46',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.216.103',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28624, 3356, 48237, 35819, 29690],
#    'community': ['3356:2',
#     '3356:22',
#     '3356:84',
#     '3356:123',
#     '3356:502',
#     '3356:901',
#     '3356:2090',
#     '28624:3356']}},
#  {'seq': 175229576347655,
#   'timestamp': '2025-05-09T07:57:34',
#   'type': 'A',
#   'attrs': {'source_id': '23-27.111.229.225',
#    'target_prefix': '212.70.48.0/24',
#    'path': [49544, 2914, 48237, 35819, 29690],
#    'community': ['2914:410',
#     '2914:1405',
#     '2914:2406',
#     '2914:3400',
#     '49544:36000',
#     '49544:36065']}},
#  {'seq': 727745554677773,
#   'timestamp': '2025-05-09T10:04:10',
#   'type': 'A',
# ...
#    'target_prefix': '212.70.48.0/24',
#    'path': [134823, 3491, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1405',
#     '2914:2406',
#     '2914:3400',
#     '3491:4000',
#     '3491:4004',
#     '3491:9002',
#     '19905:1300',
#     '19905:2216',
#     '38042:10016',
#     '38042:15003']}},
#  {'seq': 564507571716097,
#   'timestamp': '2025-05-09T13:39:06',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.208.208',
#    'target_prefix': '212.70.48.0/24',
#    'path': [12956, 3257, 19905],
#    'community': ['12956:4001', '12956:4013']}},
#  {'seq': 90822353682433,
#   'timestamp': '2025-05-09T13:39:07',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.190',
#    'target_prefix': '212.70.48.0/24',
#    'path': [37239, 37468, 12956, 2914, 19905],
#    'community': ['37468:332']}},
#  {'seq': 157716751253505,
#   'timestamp': '2025-05-09T13:39:07',
#   'type': 'A',
#   'attrs': {'source_id': '24-5.188.4.211',
#    'target_prefix': '212.70.48.0/24',
#    'path': [46997, 38008, 3491, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8855',
#     '3257:50003',
#     '3257:50130',
#     '3257:56500',
#     '3257:56501',
#     '3491:4000',
#     '3491:4015',
#     '3491:9002',
#     '38008:103']}},
#  {'seq': 217933135675393,
#   'timestamp': '2025-05-09T13:39:07',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.249',
#    'target_prefix': '212.70.48.0/24',
#    'path': [49434, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1203',
#     '2914:2201',
#     '2914:3200',
#     '19905:1200',
#     '19905:2218',
#     '49434:101',
#     '49434:201',
#     '49434:301',
#     '49434:1000',
#     '49434:1003']}},
#  {'seq': 348201781493761,
#   'timestamp': '2025-05-09T13:39:07',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.103',
#    'target_prefix': '212.70.48.0/24',
#    'path': [196621, 8758, 8220, 6453, 19905],
#    'community': ['8220:65000',
#     '8220:65030',
#     '8220:65401',
#     '8758:110',
#     '8758:300']}},
#  {'seq': 457314293186561,
#   'timestamp': '2025-05-09T13:39:07',
#   'type': 'A',
#   'attrs': {'source_id': '25-103.152.35.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [38008, 3491, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8855',
#     '3257:50003',
#     '3257:50130',
#     '3257:56500',
#     '3257:56501',
#     '3491:4000',
#     '3491:4015',
#     '3491:9002',
#     '38008:103']}},
#  {'seq': 403509524955137,
#   'timestamp': '2025-05-09T13:39:08',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.172',
#    'target_prefix': '212.70.48.0/24',
#    'path': [58308, 59689, 30781, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1203',
#     '2914:2201',
#     '2914:3200',
#     '19905:1200',
#     '19905:2218',
#     '30781:22009',
#     '30781:31000',
#     '30781:31041']}},
#  {'seq': 416129972174849,
#   'timestamp': '2025-05-09T13:39:08',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.194.186',
#    'target_prefix': '212.70.48.0/24',
#    'path': [12779, 3257, 19905],
#    'community': ['12779:10201', '12779:65098']}},
#  {'seq': 452856247943169,
#   'timestamp': '2025-05-09T13:39:08',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.209.243',
#    'target_prefix': '212.70.48.0/24',
#    'path': [271253, 6453, 19905],
#    'community': []}},
#  {'seq': 457314295545857,
#   'timestamp': '2025-05-09T13:39:08',
#   'type': 'A',
#   'attrs': {'source_id': '25-27.50.36.146',
#    'target_prefix': '212.70.48.0/24',
#    'path': [134823, 3491, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8855',
#     '3257:50003',
#     '3257:50130',
#     '3257:56500',
#     '3257:56501',
#     '3491:4000',
#     '3491:4015',
#     '3491:9002',
#     '38042:10016',
#     '38042:15003']}},
#  {'seq': 457314295873537,
#   'timestamp': '2025-05-09T13:39:08',
#   'type': 'A',
#   'attrs': {'source_id': '25-154.18.4.110',
#    'target_prefix': '212.70.48.0/24',
#    'path': [134823, 3491, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8855',
#     '3257:50003',
#     '3257:50130',
#     '3257:56500',
#     '3257:56501',
#     '3491:4000',
#     '3491:4015',
#     '3491:9002',
#     '38042:10016',
#     '38042:15003']}},
#  {'seq': 928912915300353,
#   'timestamp': '2025-05-09T13:39:08',
#   'type': 'A',
#   'attrs': {'source_id': '00-193.0.0.56',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3333, 1136, 2914, 19905],
#    'community': []}},
#  {'seq': 208832068911105,
#   'timestamp': '2025-05-09T13:39:09',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.66.65',
#    'target_prefix': '212.70.48.0/24',
#    'path': [12779, 2914, 19905],
#    'community': ['12779:65098']}},
#  {'seq': 288264450211841,
#   'timestamp': '2025-05-09T13:39:09',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.55',
#    'target_prefix': '212.70.48.0/24',
#    'path': [35600, 35625, 3257, 19905],
#    'community': ['35600:35625', '35600:65535', '65512:20002']}},
#  {'seq': 377491315490817,
#   'timestamp': '2025-05-09T13:39:09',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.246',
#    'target_prefix': '212.70.48.0/24',
#    'path': [51786, 15623, 3303, 6453, 19905],
#    'community': ['15623:1000', '15623:1014']}},
#  {'seq': 859949791903745,
#   'timestamp': '2025-05-09T13:39:09',
#   'type': 'A',
#   'attrs': {'source_id': '00-202.150.221.37',
#    'target_prefix': '212.70.48.0/24',
#    'path': [38001, 6939, 6453, 19905],
#    'community': []}},
#  {'seq': 558155000709121,
#   'timestamp': '2025-05-09T13:39:10',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.210.85',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25160, 2914, 19905],
#    'community': ['25160:22010',
#     '2914:410',
#     '2914:1203',
#     '2914:2201',
#     '2914:3200',
#     '19905:1200',
#     '19905:2218']}},
#  {'seq': 609979242184705,
#   'timestamp': '2025-05-09T13:39:10',
#   'type': 'A',
#   'attrs': {'source_id': '25-102.220.16.1',
#    'target_prefix': '212.70.48.0/24',
#    'path': [328840, 60171, 6939, 6453, 19905],
#    'community': ['60171:100', '60171:110', '60171:112', '64525:51']}},
#  {'seq': 157292702859265,
#   'timestamp': '2025-05-09T13:39:11',
#   'type': 'A',
#   'attrs': {'source_id': '16-198.32.243.133',
#    'target_prefix': '212.70.48.0/24',
#    'path': [199524, 3257, 19905],
#    'community': []}},
#  {'seq': 608232007663617,
#   'timestamp': '2025-05-09T13:39:11',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.195.171',
#    'target_prefix': '212.70.48.0/24',
#    'path': [64475, 3320, 3257, 19905],
#    'community': ['3257:3257',
#     '3320:1276',
#     '3320:2010',
#     '3320:9020',
#     '64475:201',
#     '64475:210']}},
#  {'seq': 743873101365249,
#   'timestamp': '2025-05-09T13:39:11',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.211.237',
#    'target_prefix': '212.70.48.0/24',
#    'path': [199938, 15943, 3257, 19905],
#    'community': []}},
#  {'seq': 46051796844545,
#   'timestamp': '2025-05-09T13:39:12',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.51',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41327, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8052',
#     '3257:50001',
#     '3257:50110',
#     '3257:54900',
#     '3257:54901',
#     '17152:0',
#     '41327:4400',
#     '41327:10001',
#     '41327:11000',
#     '41327:11002']}},
#  {'seq': 55903091490817,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.66.225',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50877, 49289, 9002, 3257, 19905],
#    'community': ['50877:1030']}},
#  {'seq': 199418381074433,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '14-198.32.176.3',
#    'target_prefix': '212.70.48.0/24',
#    'path': [1280, 2914, 19905],
#    'community': []}},
#  {'seq': 239990809493505,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '10-217.29.67.13',
#    'target_prefix': '212.70.48.0/24',
#    'path': [57111, 41327, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8052',
#     '3257:50001',
#     '3257:50110',
#     '3257:54900',
#     '3257:54901',
#     '17152:0',
#     '41327:4400',
#     '41327:10001',
#     '41327:11000',
#     '41327:11003']}},
#  {'seq': 377491320406017,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.246',
#    'target_prefix': '212.70.48.0/24',
#    'path': [51786, 15623, 3303, 6453, 19905],
#    'community': ['15623:1000', '15623:1014']}},
#  {'seq': 445922872983553,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.15',
#    'target_prefix': '212.70.48.0/24',
#    'path': [15623, 3303, 6453, 19905],
#    'community': ['15623:1000', '15623:1014']}},
#  {'seq': 500486954090497,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.212.10',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50629, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1206',
#     '2914:2203',
#     '2914:3200',
#     '19905:1200',
#     '19905:2215',
#     '50629:180',
#     '50629:302',
#     '50629:10003',
#     '50629:10108',
#     '50629:10214']}},
#  {'seq': 539555392913409,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '20-91.206.52.117',
#    'target_prefix': '212.70.48.0/24',
#    'path': [25091, 3257, 19905],
#    'community': ['3257:4000',
#     '3257:8052',
#     '3257:50001',
#     '3257:50110',
#     '3257:54900',
#     '3257:54901',
#     '25091:11303']}},
#  {'seq': 568399683256321,
#   'timestamp': '2025-05-09T13:39:13',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.194.240',
#    'target_prefix': '212.70.48.0/24',
#    'path': [50629, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1201',
#     '2914:2202',
#     '2914:3200',
#     '19905:1200',
#     '19905:2217',
#     '50629:0',
#     '50629:180',
#     '50629:302',
#     '50629:10001',
#     '50629:10105']}},
#  {'seq': 228201428287489,
#   'timestamp': '2025-05-09T13:39:14',
#   'type': 'A',
#   'attrs': {'source_id': '05-193.203.0.157',
#    'target_prefix': '212.70.48.0/24',
#    'path': [35369, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1201',
#     '2914:2202',
#     '2914:3200',
#     '19905:1200',
#     '19905:2217',
#     '35369:13',
#     '35369:24040']}},
#  {'seq': 478929652416513,
#   'timestamp': '2025-05-09T13:39:15',
#   'type': 'A',
#   'attrs': {'source_id': '01-5.57.81.216',
#    'target_prefix': '212.70.48.0/24',
#    'path': [35266, 2914, 19905],
#    'community': ['2914:410',
#     '2914:1203',
#     '2914:2201',
#     '2914:3200',
#     '19905:1200',
#     '19905:2218',
#     '35266:60',
#     '35266:2914']}},
#  {'seq': 564507595112449,
#   'timestamp': '2025-05-09T13:39:15',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.210.78',
#    'target_prefix': '212.70.48.0/24',
#    'path': [8529, 6453, 19905],
#    'community': []}},
#  {'seq': 564507598979073,
#   'timestamp': '2025-05-09T13:39:15',
#   'type': 'A',
#   'attrs': {'source_id': '03-80.249.209.211',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3320, 3257, 19905],
#    'community': ['3257:3257', '3320:1528', '3320:2010', '3320:9020']}},
#  {'seq': 609979264466945,
#   'timestamp': '2025-05-09T13:39:15',
#   'type': 'A',
#   'attrs': {'source_id': '25-102.220.17.28',
#    'target_prefix': '212.70.48.0/24',
#    'path': [328840, 37282, 6453, 19905],
#    'community': ['64525:61']}},
#  {'seq': 852611571974145,
#   'timestamp': '2025-05-09T13:39:15',
#   'type': 'A',
#   'attrs': {'source_id': '00-94.247.111.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [49673, 3216, 6453, 19905],
#    'community': ['3216:3000',
#     '3216:3006',
#     '6453:50',
#     '6453:2000',
#     '6453:2300',
#     '6453:2302']}},
#  {'seq': 852611573874689,
#   'timestamp': '2025-05-09T13:39:15',
#   'type': 'A',
#   'attrs': {'source_id': '00-94.247.111.254',
#    'target_prefix': '212.70.48.0/24',
#    'path': [49673, 3216, 6453, 19905],
#    'community': ['3216:3000',
#     '3216:3006',
#     '6453:50',
#     '6453:2000',
#     '6453:2300',
#     '6453:2302']}},
#  {'seq': 527980485804033,
#   'timestamp': '2025-05-09T13:39:16',
#   'type': 'A',
#   'attrs': {'source_id': '25-193.43.214.253',
#    'target_prefix': '212.70.48.0/24',
#    'path': [44097, 35625, 3257, 19905],
#    'community': ['44097:35625']}},
#  {'seq': 527980486656001,
#   'timestamp': '2025-05-09T13:39:16',
#   'type': 'A',
#   'attrs': {'source_id': '25-2001:67c:ec:253::1',
#    'target_prefix': '212.70.48.0/24',
#    'path': [44097, 35625, 3257, 19905],
#    'community': ['44097:35625']}},
#  {'seq': 727761562304513,
#   'timestamp': '2025-05-09T13:39:16',
#   'type': 'A',
#   'attrs': {'source_id': '00-217.151.205.144',
#    'target_prefix': '212.70.48.0/24',
#    'path': [20514, 2119, 6453, 19905],
#    'community': ['2119:200', '2119:205', '2119:820']}},
#  {'seq': 376733814751233,
#   'timestamp': '2025-05-09T13:39:17',
#   'type': 'A',
#   'attrs': {'source_id': '25-31.15.255.209',
#    'target_prefix': '212.70.48.0/24',
#    'path': [3212, 6939, 6453, 19905],
#    'community': ['6939:500']}},
#  {'seq': 460215173709825,
#   'timestamp': '2025-05-09T13:39:17',
#   'type': 'A',
#   'attrs': {'source_id': '25-195.69.189.4',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28910, 6453, 19905],
#    'community': []}},
#  {'seq': 149670026346497,
#   'timestamp': '2025-05-09T13:39:18',
#   'type': 'A',
#   'attrs': {'source_id': '11-198.32.160.137',
#    'target_prefix': '212.70.48.0/24',
#    'path': [19151, 2914, 19905],
#    'community': []}},
#  {'seq': 257063109591041,
#   'timestamp': '2025-05-09T13:39:18',
#   'type': 'A',
#   'attrs': {'source_id': '13-195.208.210.52',
#    'target_prefix': '212.70.48.0/24',
#    'path': [41722, 20485, 6453, 19905],
#    'community': ['20485:21507', '41722:50']}},
#  {'seq': 288264462336001,
#   'timestamp': '2025-05-09T13:39:18',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.205',
#    'target_prefix': '212.70.48.0/24',
#    'path': [29075, 2914, 19905],
#    'community': ['0:0',
#     '2914:410',
#     '2914:1203',
#     '2914:2201',
#     '2914:3200',
#     '19905:1200',
#     '19905:2218',
#     '29075:7650']}},
#  {'seq': 452856255479809,
#   'timestamp': '2025-05-09T13:39:18',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.209.243',
#    'target_prefix': '212.70.48.0/24',
#    'path': [271253, 10429, 12956, 2914, 19905],
#    'community': []}},
#  {'seq': 52725544189953,
#   'timestamp': '2025-05-09T13:39:19',
#   'type': 'A',
#   'attrs': {'source_id': '24-177.101.16.80',
#    'target_prefix': '212.70.48.0/24',
#    'path': [53046, 10881, 1916, 2914, 19905],
#    'community': ['1916:1',
#     '1916:500',
#     '1916:10501',
#     '10881:1100',
#     '53046:5000',
#     '53046:5010']}},
#  {'seq': 378774183084033,
#   'timestamp': '2025-05-09T13:39:19',
#   'type': 'A',
#   'attrs': {'source_id': '15-187.16.220.159',
#    'target_prefix': '212.70.48.0/24',
#    'path': [917, 60068, 12956, 2914, 19905],
#    'community': ['917:55551',
#     '12956:4002',
#     '12956:4020',
#     '12956:4200',
#     '57695:13000',
#     '60068:202',
#     '60068:2000',
#     '60068:2190',
#     '60068:7280']}},
#  {'seq': 81506045722625,
#   'timestamp': '2025-05-09T13:39:20',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.8.221',
#    'target_prefix': '212.70.48.0/24',
#    'path': [327804, 37271, 3257, 19905],
#    'community': []}},
#  {'seq': 119560580038657,
#   'timestamp': '2025-05-09T13:39:20',
#   'type': 'A',
#   'attrs': {'source_id': '14-198.32.176.164',
#    'target_prefix': '212.70.48.0/24',
#    'path': [19151, 2914, 19905],
#    'community': []}},
#  {'seq': 416129988755457,
#   'timestamp': '2025-05-09T13:39:20',
#   'type': 'A',
#   'attrs': {'source_id': '12-80.81.192.175',
#    'target_prefix': '212.70.48.0/24',
#    'path': [553, 2914, 19905],
#    'community': []}},
#  {'seq': 449203774423041,
#   'timestamp': '2025-05-09T13:39:20',
#   'type': 'A',
#   'attrs': {'source_id': '21-37.49.236.177',
#    'target_prefix': '212.70.48.0/24',
#    'path': [12779, 3257, 19905],
#    'community': ['12779:10201', '12779:65098']}},
#  {'seq': 176576476086273,
#   'timestamp': '2025-05-09T13:39:21',
#   'type': 'A',
#   'attrs': {'source_id': '19-196.60.9.165',
#    'target_prefix': '212.70.48.0/24',
#    'path': [917, 60068, 3491, 3257, 19905],
#    'community': ['917:59001',
#     '3257:3257',
#     '3491:3000',
#     '3491:3001',
#     '3491:9002',
#     '3491:9080',
#     '3491:9081',
#     '3491:9087',
#     '57695:13000',
#     '60068:204',
#     '60068:2000',
#     '60068:2210',
#     '60068:7180']}},
#  {'seq': 372626078367745,
#   'timestamp': '2025-05-09T13:39:21',
#   'type': 'A',
#   'attrs': {'source_id': '01-195.66.224.131',
#    'target_prefix': '212.70.48.0/24',
#    'path': [28792, 3257, 19905],
#    'community': []}},
#  ...]
