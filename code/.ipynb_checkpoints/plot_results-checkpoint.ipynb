# %%
# For Cloudflare
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import io
import numpy as np

# Globally update the font size
plt.rcParams.update({'font.size': 16})
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# Your provided data as a string
data = """
Date	No. of total prefixes	No. of new prefixes  until 23:59:59	No. of new prefix (exact len has different origin at next day
1-5-2025	4206	1	0
2-5-2025	4207	1	0
3-5-2025	4207	0	0
4-5-2025	4207	1	0
5-5-2025	4207	3	0
6-5-2025	4198	12	0
7-5-2025	4206	7	0
8-5-2025	4203	10	0
9-5-2025	4199	25	0
10-5-2025	4128	1	0
11-5-2025	4129	0	0
12-5-2025	4129	3	0
13-5-2025	4130	177	0
14-5-2025	4298	9	0
15-5-2025	4289	15	0
16-5-2025	4299	9	0
17-5-2025	4283	13	0
18-5-2025	4283	13	0
19-5-2025	4287	622	0
20-5-2025	4893	16	0
21-5-2025	4897	10	1
22-5-2025	4877	32	0
23-5-2025	4897	8	0
24-5-2025	4898	3	1
25-5-2025	4898	0	0
26-5-2025	4894	12	0
27-5-2025	4903	291	0
28-5-2025	5192	15	0
29-5-2025	5166	36	No
30-5-2025	5194	11	1
31-5-2025	5200	1	0
"""

# Read the data into a pandas DataFrame
df = pd.read_csv(io.StringIO(data), sep='\t')

# Rename columns for easier access
df.columns = [
    "Date",
    "Total Prefixes at 00:00",
    "New Prefixes on that day",
    "Prefixes with different origin next day"
]

# Convert 'Date' column to datetime objects
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# Convert other columns to numeric, coercing errors to NaN and then filling NaN with 0
df["Total Prefixes at 00:00"] = pd.to_numeric(df["Total Prefixes at 00:00"], errors='coerce').fillna(0)
df["New Prefixes on that day"] = pd.to_numeric(df["New Prefixes on that day"], errors='coerce').fillna(0)
df["Prefixes with different origin next day"] = pd.to_numeric(df["Prefixes with different origin next day"], errors='coerce').fillna(0)

# Plot setup
fig, ax = plt.subplots(figsize=(14, 7))

# Plot line for "Total Prefixes at 00:00"
ax.plot(df["Date"], df["Total Prefixes at 00:00"], marker='o', color='blue', label="Total Prefixes at 00:00", linewidth=2)

# Bars for "New Prefixes on that day" and "Prefixes with different origin next day"
bar_width = pd.Timedelta(days=0.3) # Adjust bar width as needed
bars1 = ax.bar(df["Date"] - bar_width / 2, df["New Prefixes on that day"], width=bar_width, color='red', label="New Prefixes on that day", alpha=0.7)
bars2 = ax.bar(df["Date"] + bar_width / 2, df["Prefixes with different origin next day"], width=bar_width, color='green', label="Prefixes with different origin next day", alpha=0.7)

# --- X-axis formatting (show all dates from 1 to 31 within the data range) ---
date_form = mdates.DateFormatter("%d-%m-%Y")
ax.xaxis.set_major_formatter(date_form)

min_date = df["Date"].min()
max_date = df["Date"].max()
all_dates_in_range = pd.date_range(start=min_date.floor('D'), end=max_date.ceil('D'), freq='D')
ax.set_xticks(all_dates_in_range)
plt.xticks(rotation=90) # Rotate labels for better readability
# --- End of x-axis formatting ---

# --- Y-axis formatting (show y-ticks) ---
y_min = 0
y_max_total = df["Total Prefixes at 00:00"].max()
y_max_new_eod = df["New Prefixes on that day"].max()
y_max_diff_origin = df["Prefixes with different origin next day"].max()

y_max_data = max(y_max_total, y_max_new_eod, y_max_diff_origin)

# Increased padding slightly to accommodate bar labels
y_max_plot = y_max_data * 1.15

if y_max_data > 1000:
    y_tick_step = 500
elif y_max_data > 100:
    y_tick_step = 50
else:
    y_tick_step = 10

if y_tick_step == 0:
    y_ticks = [y_min, y_max_plot]
else:
    y_ticks = np.arange(y_min, y_max_plot + y_tick_step, y_tick_step)

ax.set_yticks(y_ticks)
# --- End of y-axis formatting ---

# --- Add values on top of bar plots ---
def autolabel(bars, color): # Added 'color' parameter
    """Attach a text label above each bar in *bars*, displaying its height."""
    for bar in bars:
        height = bar.get_height()
        if height > 0: # Only label if height is greater than 0
            ax.text(bar.get_x() + bar.get_width() / 2, height,
                    f'{int(height)}',
                    ha='center', va='bottom', fontsize=12, color=color) # Use the passed color

autolabel(bars1, 'red') # Pass 'green' for the first set of bars
autolabel(bars2, 'green')   # Pass 'red' for the second set of bars
# --- End of adding values ---

# General plot formatting
plt.title("Prefix Monitoring Over Time (Cloudflare)")
plt.xlabel("Date")
plt.ylabel("Count")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper left') 
plt.tight_layout()
plt.show()

# %%
# For Akamai

# For Cloudflare
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import io
import numpy as np

# Globally update the font size
plt.rcParams.update({'font.size': 16})
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# Your provided data as a string
data = """
Date	No. of total prefixes	No. of new prefixes  until 23:59:59	No. of new prefix (exact len has different origin at next day
1-5-2025	399	0	0
2-5-2025	399	0	0
3-5-2025	399	0	0
4-5-2025	399	1	1
5-5-2025	399	0	0
6-5-2025	399	0	0
7-5-2025	399	0	0
8-5-2025	399	0	0
9-5-2025	399	0	0
10-5-2025	396	0	0
11-5-2025	396	0	0
12-5-2025	396	0	0
13-5-2025	396	1	0
14-5-2025	396	4	3
15-5-2025	399	0	0
16-5-2025	399	0	0
17-5-2025	399	0	0
18-5-2025	399	0	0
19-5-2025	399	0	0
20-5-2025	399	0	0
21-5-2025	399	0	0
22-5-2025	399	0	0
23-5-2025	399	0	0
24-5-2025	399	0	0
25-5-2025	399	0	0
26-5-2025	399	0	0
27-5-2025	399	0	0
28-5-2025	399	1	0
29-5-2025	400	0	0
30-5-2025	400	0	0
31-5-2025	400	0	0
"""

# Read the data into a pandas DataFrame
df = pd.read_csv(io.StringIO(data), sep='\t')

# Rename columns for easier access
df.columns = [
    "Date",
    "Total Prefixes at 00:00",
    "New Prefixes on that day",
    "Prefixes with different origin next day"
]

# Convert 'Date' column to datetime objects
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# Convert other columns to numeric, coercing errors to NaN and then filling NaN with 0
df["Total Prefixes at 00:00"] = pd.to_numeric(df["Total Prefixes at 00:00"], errors='coerce').fillna(0)
df["New Prefixes on that day"] = pd.to_numeric(df["New Prefixes on that day"], errors='coerce').fillna(0)
df["Prefixes with different origin next day"] = pd.to_numeric(df["Prefixes with different origin next day"], errors='coerce').fillna(0)

# Plot setup
fig, ax = plt.subplots(figsize=(14, 7))

# Plot line for "Total Prefixes at 00:00"
ax.plot(df["Date"], df["Total Prefixes at 00:00"], marker='o', color='blue', label="Total Prefixes at 00:00", linewidth=2)

# Bars for "New Prefixes on that day" and "Prefixes with different origin next day"
bar_width = pd.Timedelta(days=0.3) # Adjust bar width as needed
bars1 = ax.bar(df["Date"] - bar_width / 2, df["New Prefixes on that day"], width=bar_width, color='red', label="New Prefixes on that day", alpha=0.7)
bars2 = ax.bar(df["Date"] + bar_width / 2, df["Prefixes with different origin next day"], width=bar_width, color='green', label="Prefixes with different origin next day", alpha=0.7)

# --- X-axis formatting (show all dates from 1 to 31 within the data range) ---
date_form = mdates.DateFormatter("%d-%m-%Y")
ax.xaxis.set_major_formatter(date_form)

min_date = df["Date"].min()
max_date = df["Date"].max()
all_dates_in_range = pd.date_range(start=min_date.floor('D'), end=max_date.ceil('D'), freq='D')
ax.set_xticks(all_dates_in_range)
plt.xticks(rotation=90) # Rotate labels for better readability
# --- End of x-axis formatting ---

# --- Y-axis formatting (show y-ticks) ---
y_min = 0
y_max_total = df["Total Prefixes at 00:00"].max()
y_max_new_eod = df["New Prefixes on that day"].max()
y_max_diff_origin = df["Prefixes with different origin next day"].max()

y_max_data = max(y_max_total, y_max_new_eod, y_max_diff_origin)

# Increased padding slightly to accommodate bar labels
y_max_plot = y_max_data * 1.15

if y_max_data > 1000:
    y_tick_step = 500
elif y_max_data > 100:
    y_tick_step = 50
else:
    y_tick_step = 10

if y_tick_step == 0:
    y_ticks = [y_min, y_max_plot]
else:
    y_ticks = np.arange(y_min, y_max_plot + y_tick_step, y_tick_step)

ax.set_yticks(y_ticks)
# --- End of y-axis formatting ---

# --- Add values on top of bar plots ---
def autolabel(bars, color): # Added 'color' parameter
    """Attach a text label above each bar in *bars*, displaying its height."""
    for bar in bars:
        height = bar.get_height()
        if height > 0: # Only label if height is greater than 0
            ax.text(bar.get_x() + bar.get_width() / 2, height,
                    f'{int(height)}',
                    ha='center', va='bottom', fontsize=12, color=color) # Use the passed color

autolabel(bars1, 'red') # Pass 'green' for the first set of bars
autolabel(bars2, 'green')   # Pass 'red' for the second set of bars
# --- End of adding values ---

# General plot formatting
plt.title("Prefix Monitoring Over Time (Akamai)")
plt.xlabel("Date")
plt.ylabel("Count")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='center left') 
plt.tight_layout()
plt.show()

# %%
# For Vercara

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import io
import numpy as np

# Globally update the font size
plt.rcParams.update({'font.size': 16})
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# Your provided data as a string
data = """
Date	No. of total prefixes	No. of new prefixes  until 23:59:59	No. of new prefix (exact len has different origin at next day
1-5-2025	174	6	5
2-5-2025	175	2	1
3-5-2025	177	5	1
4-5-2025	177	2	0
5-5-2025	177	3	2
6-5-2025	178	26	3
7-5-2025	178	1	1
8-5-2025	178	13	4
9-5-2025	185	1	1
10-5-2025	183	18	2
11-5-2025	180	5	1
12-5-2025	183	5	2
13-5-2025	180	4	1
14-5-2025	179	6	3
15-5-2025	182	8	5
16-5-2025	183	1	1
17-5-2025	180	6	2
18-5-2025	181	27	2
19-5-2025	206	2	0
20-5-2025	182	11	3
21-5-2025	186	8	6
22-5-2025	190	5	3
23-5-2025	186	8	1
24-5-2025	188	6	1
25-5-2025	191	3	2
26-5-2025	189	10	2
27-5-2025	191	11	8
28-5-2025	188	3	0
29-5-2025	189	3	1
30-5-2025	184	5	2
"""

# Read the data into a pandas DataFrame
df = pd.read_csv(io.StringIO(data), sep='\t')

# Rename columns for easier access
df.columns = [
    "Date",
    "Total Prefixes at 00:00",
    "New Prefixes on that day",
    "Prefixes with different origin next day"
]

# Convert 'Date' column to datetime objects
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# Convert other columns to numeric, coercing errors to NaN and then filling NaN with 0
df["Total Prefixes at 00:00"] = pd.to_numeric(df["Total Prefixes at 00:00"], errors='coerce').fillna(0)
df["New Prefixes on that day"] = pd.to_numeric(df["New Prefixes on that day"], errors='coerce').fillna(0)
df["Prefixes with different origin next day"] = pd.to_numeric(df["Prefixes with different origin next day"], errors='coerce').fillna(0)

# Plot setup
fig, ax = plt.subplots(figsize=(14, 7))

# Plot line for "Total Prefixes at 00:00"
ax.plot(df["Date"], df["Total Prefixes at 00:00"], marker='o', color='blue', label="Total Prefixes at 00:00", linewidth=2)

# Bars for "New Prefixes on that day" and "Prefixes with different origin next day"
bar_width = pd.Timedelta(days=0.3) # Adjust bar width as needed
bars1 = ax.bar(df["Date"] - bar_width / 2, df["New Prefixes on that day"], width=bar_width, color='red', label="New Prefixes on that day", alpha=0.7)
bars2 = ax.bar(df["Date"] + bar_width / 2, df["Prefixes with different origin next day"], width=bar_width, color='green', label="Prefixes with different origin next day", alpha=0.7)

# --- X-axis formatting (show all dates from 1 to 31 within the data range) ---
date_form = mdates.DateFormatter("%d-%m-%Y")
ax.xaxis.set_major_formatter(date_form)

min_date = df["Date"].min()
max_date = df["Date"].max()
all_dates_in_range = pd.date_range(start=min_date.floor('D'), end=max_date.ceil('D'), freq='D')
ax.set_xticks(all_dates_in_range)
plt.xticks(rotation=90) # Rotate labels for better readability
# --- End of x-axis formatting ---

# --- Y-axis formatting (show y-ticks) ---
y_min = 0
y_max_total = df["Total Prefixes at 00:00"].max()
y_max_new_eod = df["New Prefixes on that day"].max()
y_max_diff_origin = df["Prefixes with different origin next day"].max()

y_max_data = max(y_max_total, y_max_new_eod, y_max_diff_origin)

# Increased padding slightly to accommodate bar labels
y_max_plot = y_max_data * 1.15

if y_max_data > 1000:
    y_tick_step = 500
elif y_max_data > 100:
    y_tick_step = 50
else:
    y_tick_step = 10

if y_tick_step == 0:
    y_ticks = [y_min, y_max_plot]
else:
    y_ticks = np.arange(y_min, y_max_plot + y_tick_step, y_tick_step)

ax.set_yticks(y_ticks)
# --- End of y-axis formatting ---

# --- Add values on top of bar plots ---
def autolabel(bars, color): # Added 'color' parameter
    """Attach a text label above each bar in *bars*, displaying its height."""
    for bar in bars:
        height = bar.get_height()
        if height > 0: # Only label if height is greater than 0
            ax.text(bar.get_x() + bar.get_width() / 2, height,
                    f'{int(height)}',
                    ha='center', va='bottom', fontsize=12, color=color) # Use the passed color

autolabel(bars1, 'red') # Pass 'green' for the first set of bars
autolabel(bars2, 'green')   # Pass 'red' for the second set of bars
# --- End of adding values ---

# General plot formatting
plt.title("Prefix Monitoring Over Time (Vercara)")
plt.xlabel("Date")
plt.ylabel("Count")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper left') 
plt.tight_layout()
plt.show()

# %%
# For Imperva

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import io
import numpy as np

# Globally update the font size
plt.rcParams.update({'font.size': 16})
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# Your provided data as a string
data = """
Date	No. of total prefixes	No. of new prefixes  until 23:59:59	No. of new prefix (exact len has different origin at next day
1-5-2025	1514	0
2-5-2025	1514	3
3-5-2025	1516	1
4-5-2025	1517	6
5-5-2025	1517	6
6-5-2025	1516	6
7-5-2025	1522	0
8-5-2025	1522	0
9-5-2025	1521	6
10-5-2025	1521	0
11-5-2025	1521	1
12-5-2025	1522	0
13-5-2025	1521	9
14-5-2025	1523	0
15-5-2025	1523	4
16-5-2025	1527	0
17-5-2025	1526	0
18-5-2025	1526	0
19-5-2025	1526	0
20-5-2025	1526	12
21-5-2025	1530	6
22-5-2025	1530	1
23-5-2025	1526	1
24-5-2025	1527	1
25-5-2025	1528	0
26-5-2025	1528	0
27-5-2025	1525	1
28-5-2025	1519	2
29-5-2025	1514	0
30-5-2025	1514	4
"""

# Read the data into a pandas DataFrame
df = pd.read_csv(io.StringIO(data), sep='\t')

# Rename columns for easier access
df.columns = [
    "Date",
    "Total Prefixes at 00:00",
    "New Prefixes on that day",
    "Prefixes with different origin next day"
]

# Convert 'Date' column to datetime objects
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# Convert other columns to numeric, coercing errors to NaN and then filling NaN with 0
df["Total Prefixes at 00:00"] = pd.to_numeric(df["Total Prefixes at 00:00"], errors='coerce').fillna(0)
df["New Prefixes on that day"] = pd.to_numeric(df["New Prefixes on that day"], errors='coerce').fillna(0)
df["Prefixes with different origin next day"] = pd.to_numeric(df["Prefixes with different origin next day"], errors='coerce').fillna(0)

# Plot setup
fig, ax = plt.subplots(figsize=(14, 7))

# Plot line for "Total Prefixes at 00:00"
ax.plot(df["Date"], df["Total Prefixes at 00:00"], marker='o', color='blue', label="Total Prefixes at 00:00", linewidth=2)

# Bars for "New Prefixes on that day" and "Prefixes with different origin next day"
bar_width = pd.Timedelta(days=0.3) # Adjust bar width as needed
bars1 = ax.bar(df["Date"] - bar_width / 2, df["New Prefixes on that day"], width=bar_width, color='red', label="New Prefixes on that day", alpha=0.7)
bars2 = ax.bar(df["Date"] + bar_width / 2, df["Prefixes with different origin next day"], width=bar_width, color='green', label="Prefixes with different origin next day", alpha=0.7)

# --- X-axis formatting (show all dates from 1 to 31 within the data range) ---
date_form = mdates.DateFormatter("%d-%m-%Y")
ax.xaxis.set_major_formatter(date_form)

min_date = df["Date"].min()
max_date = df["Date"].max()
all_dates_in_range = pd.date_range(start=min_date.floor('D'), end=max_date.ceil('D'), freq='D')
ax.set_xticks(all_dates_in_range)
plt.xticks(rotation=90) # Rotate labels for better readability
# --- End of x-axis formatting ---

# --- Y-axis formatting (show y-ticks) ---
y_min = 0
y_max_total = df["Total Prefixes at 00:00"].max()
y_max_new_eod = df["New Prefixes on that day"].max()
y_max_diff_origin = df["Prefixes with different origin next day"].max()

y_max_data = max(y_max_total, y_max_new_eod, y_max_diff_origin)

# Increased padding slightly to accommodate bar labels
y_max_plot = y_max_data * 1.15

if y_max_data > 1000:
    y_tick_step = 500
elif y_max_data > 100:
    y_tick_step = 50
else:
    y_tick_step = 10

if y_tick_step == 0:
    y_ticks = [y_min, y_max_plot]
else:
    y_ticks = np.arange(y_min, y_max_plot + y_tick_step, y_tick_step)

ax.set_yticks(y_ticks)
# --- End of y-axis formatting ---

# --- Add values on top of bar plots ---
def autolabel(bars, color): # Added 'color' parameter
    """Attach a text label above each bar in *bars*, displaying its height."""
    for bar in bars:
        height = bar.get_height()
        if height > 0: # Only label if height is greater than 0
            ax.text(bar.get_x() + bar.get_width() / 2, height,
                    f'{int(height)}',
                    ha='center', va='bottom', fontsize=12, color=color) # Use the passed color

autolabel(bars1, 'red') # Pass 'green' for the first set of bars
autolabel(bars2, 'green')   # Pass 'red' for the second set of bars
# --- End of adding values ---

# General plot formatting
plt.title("Prefix Monitoring Over Time (Imperva)")
plt.xlabel("Date")
plt.ylabel("Count")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='center left') 
plt.tight_layout()
plt.show()

# %%
# For Radware

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import io
import numpy as np

# Globally update the font size
plt.rcParams.update({'font.size': 16})
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# Your provided data as a string
data = """
Date	No. of total prefixes	No. of new prefixes  until 23:59:59	No. of new prefix (exact len has different origin at next day
1-5-2025	187	2
2-5-2025	189	0
3-5-2025	189	0
4-5-2025	189	0
5-5-2025	189	0
6-5-2025	189	2
7-5-2025	188	0
8-5-2025	182	1
9-5-2025	182	2
10-5-2025	182	0
11-5-2025	182	2
12-5-2025	182	3
13-5-2025	183	2
14-5-2025	183	3
15-5-2025	184	5
16-5-2025	182	0
17-5-2025	182	4
18-5-2025	186	0
19-5-2025	186	3
20-5-2025	187	1
21-5-2025	187	3
22-5-2025	187	2
23-5-2025	188	2
24-5-2025	185	0
25-5-2025	185	0
26-5-2025	185	0
27-5-2025	185	1
28-5-2025	182	1
29-5-2025	182	1
30-5-2025	183	2
31-5-2025	182	0
"""

# Read the data into a pandas DataFrame
df = pd.read_csv(io.StringIO(data), sep='\t')

# Rename columns for easier access
df.columns = [
    "Date",
    "Total Prefixes at 00:00",
    "New Prefixes on that day",
    "Prefixes with different origin next day"
]

# Convert 'Date' column to datetime objects
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# Convert other columns to numeric, coercing errors to NaN and then filling NaN with 0
df["Total Prefixes at 00:00"] = pd.to_numeric(df["Total Prefixes at 00:00"], errors='coerce').fillna(0)
df["New Prefixes on that day"] = pd.to_numeric(df["New Prefixes on that day"], errors='coerce').fillna(0)
df["Prefixes with different origin next day"] = pd.to_numeric(df["Prefixes with different origin next day"], errors='coerce').fillna(0)

# Plot setup
fig, ax = plt.subplots(figsize=(14, 7))

# Plot line for "Total Prefixes at 00:00"
ax.plot(df["Date"], df["Total Prefixes at 00:00"], marker='o', color='blue', label="Total Prefixes at 00:00", linewidth=2)

# Bars for "New Prefixes on that day" and "Prefixes with different origin next day"
bar_width = pd.Timedelta(days=0.3) # Adjust bar width as needed
bars1 = ax.bar(df["Date"] - bar_width / 2, df["New Prefixes on that day"], width=bar_width, color='red', label="New Prefixes on that day", alpha=0.7)
bars2 = ax.bar(df["Date"] + bar_width / 2, df["Prefixes with different origin next day"], width=bar_width, color='green', label="Prefixes with different origin next day", alpha=0.7)

# --- X-axis formatting (show all dates from 1 to 31 within the data range) ---
date_form = mdates.DateFormatter("%d-%m-%Y")
ax.xaxis.set_major_formatter(date_form)

min_date = df["Date"].min()
max_date = df["Date"].max()
all_dates_in_range = pd.date_range(start=min_date.floor('D'), end=max_date.ceil('D'), freq='D')
ax.set_xticks(all_dates_in_range)
plt.xticks(rotation=90) # Rotate labels for better readability
# --- End of x-axis formatting ---

# --- Y-axis formatting (show y-ticks) ---
y_min = 0
y_max_total = df["Total Prefixes at 00:00"].max()
y_max_new_eod = df["New Prefixes on that day"].max()
y_max_diff_origin = df["Prefixes with different origin next day"].max()

y_max_data = max(y_max_total, y_max_new_eod, y_max_diff_origin)

# Increased padding slightly to accommodate bar labels
y_max_plot = y_max_data * 1.15

if y_max_data > 1000:
    y_tick_step = 500
elif y_max_data > 100:
    y_tick_step = 50
else:
    y_tick_step = 10

if y_tick_step == 0:
    y_ticks = [y_min, y_max_plot]
else:
    y_ticks = np.arange(y_min, y_max_plot + y_tick_step, y_tick_step)

ax.set_yticks(y_ticks)
# --- End of y-axis formatting ---

# --- Add values on top of bar plots ---
def autolabel(bars, color): # Added 'color' parameter
    """Attach a text label above each bar in *bars*, displaying its height."""
    for bar in bars:
        height = bar.get_height()
        if height > 0: # Only label if height is greater than 0
            ax.text(bar.get_x() + bar.get_width() / 2, height,
                    f'{int(height)}',
                    ha='center', va='bottom', fontsize=12, color=color) # Use the passed color

autolabel(bars1, 'red') # Pass 'green' for the first set of bars
autolabel(bars2, 'green')   # Pass 'red' for the second set of bars
# --- End of adding values ---

# General plot formatting
plt.title("Prefix Monitoring Over Time (Radware)")
plt.xlabel("Date")
plt.ylabel("Count")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='center left') 
plt.tight_layout()
plt.show()
